# %%
import pandas as pd
truck_data=pd.read_csv('trucks.csv')

# %%
truck_data
# Out:
#    driverid truckid         model  jun13_miles  jun13_gas  may13_miles  \
# 0        A1      A1  Freightliner         9217       1914         8769
# 1        A2      A2          Ford        12058       2335        14314
# 2        A3      A3          Ford        13652       2899        12075
# 3        A4      A4      Kenworth        12687       2439        10680
# 4        A5      A5          Hino        10233       1825        14634
# 5        A6      A6   Caterpillar        14488       2883        13317
# 6        A7      A7          Ford        10938       2231        12080
# 7        A8      A8      Navistar        11392       2280         8922
# 8        A9      A9         Volvo        12601       2515         9707
# 9       A10     A10     Peterbilt        13699       2583        11583
# 10      A11     A11     Peterbilt        12447       2596        15726
# 11      A12     A12   Caterpillar        10006       2055        10307
# ...

# %% [markdown]
# ### Cannot access a single element like this in a DataFrame.
# truck_data[[1]]

# %%
truck_data[:3]
# Out:
#   driverid truckid         model  jun13_miles  jun13_gas  may13_miles  \
# 0       A1      A1  Freightliner         9217       1914         8769
# 1       A2      A2          Ford        12058       2335        14314
# 2       A3      A3          Ford        13652       2899        12075
#
#    may13_gas  apr13_miles  apr13_gas  mar13_miles    ...      may09_miles  \
# 0       1892        14234       3008        11519    ...            12073
# 1       2648        11050       2323        14114    ...            13912
# 2       2603        12277       2792         9642    ...             9821
#
#    may09_gas  apr09_miles  apr09_gas  mar09_miles  mar09_gas  feb09_miles  \
# 0       2642        15276       2642         9880       2642        13861
# 1       1827        11892       1827        15158       1827        12774
# 2       3064        15224       3064        11209       3064        14203
#
#    feb09_gas  jan09_miles  jan09_gas
# 0       2642        11176       2642
# ...

# %%
truck_data.loc[[1]]
# Out:
#   driverid truckid model  jun13_miles  jun13_gas  may13_miles  may13_gas  \
# 1       A2      A2  Ford        12058       2335        14314       2648
#
#    apr13_miles  apr13_gas  mar13_miles    ...      may09_miles  may09_gas  \
# 1        11050       2323        14114    ...            13912       1827
#
#    apr09_miles  apr09_gas  mar09_miles  mar09_gas  feb09_miles  feb09_gas  \
# 1        11892       1827        15158       1827        12774       1827
#
#    jan09_miles  jan09_gas
# 1        11743       1827
#
# [1 rows x 111 columns]

# %%
truck_data.loc[1]
# Out:
# driverid          A2
# truckid           A2
# model           Ford
# jun13_miles    12058
# jun13_gas       2335
# may13_miles    14314
# may13_gas       2648
# apr13_miles    11050
# apr13_gas       2323
# mar13_miles    14114
# mar13_gas       3157
# feb13_miles    13583
# feb13_gas       2346
# jan13_miles    15362
# jan13_gas       3353
# dec12_miles    13608
# dec12_gas       2607
# nov12_miles    11236
# nov12_gas       2597
# oct12_miles    11380
# oct12_gas       1939
# sep12_miles    12934
# sep12_gas       2324
# aug12_miles    11848
# aug12_gas       2301
# jul12_miles    13206
# jul12_gas       3114
# jun12_miles    15316
# jun12_gas       3344
# may12_miles    13838
#                ...
# mar10_miles     9406
# mar10_gas       1827
# feb10_miles    14755
# feb10_gas       1827
# jan10_miles    14043
# jan10_gas       1827
# dec09_miles    11656
# dec09_gas       1827
# nov09_miles    14744
# nov09_gas       1827
# oct09_miles    13797
# oct09_gas       1827
# ...

# %%
truck_data.iloc[1:,2:]
# Out:
#            model  jun13_miles  jun13_gas  may13_miles  may13_gas  apr13_miles  \
# 1           Ford        12058       2335        14314       2648        11050
# 2           Ford        13652       2899        12075       2603        12277
# 3       Kenworth        12687       2439        10680       2083        11071
# 4           Hino        10233       1825        14634       3450         9281
# 5    Caterpillar        14488       2883        13317       3091        10927
# 6           Ford        10938       2231        12080       2142        13539
# 7       Navistar        11392       2280         8922       1834        11422
# 8          Volvo        12601       2515         9707       1869        11914
# 9      Peterbilt        13699       2583        11583       2077        12833
# 10     Peterbilt        12447       2596        15726       3145        11461
# 11   Caterpillar        10006       2055        10307       2187        13044
# ...

# %%
truck_data.iat[3,0]
# Out:
# 'A4'

# %%
truck_data.reset_index('model',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-f484d7ee957f> in <module>()
# ----> 1 truck_data.reset_index('model',inplace=True)
#
# /home/deepak-kumar-jha/Downloads/ENTER/lib/python3.6/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    3053                 # to ndarray and maybe infer different dtype
#    3054                 level_values = _maybe_casted_values(lev, lab)
# -> 3055                 if level is None or i in level:
#    3056                     new_obj.insert(0, name, level_values)
#    3057
#
# TypeError: 'in <string>' requires string as left operand, not int

# %%
truck_data.loc['Ford',:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/deepak-kumar-jha/Downloads/ENTER/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# /home/deepak-kumar-jha/Downloads/ENTER/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [Ford] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-53a36c92cd2e> in <module>()
# ----> 1 truck_data.loc['Ford',:]
#
# ...

# %%
truck_data
# Out:
#              driverid truckid  jun13_miles  jun13_gas  may13_miles  may13_gas  \
# model
# Freightliner       A1      A1         9217       1914         8769       1892
# Ford               A2      A2        12058       2335        14314       2648
# Ford               A3      A3        13652       2899        12075       2603
# Kenworth           A4      A4        12687       2439        10680       2083
# Hino               A5      A5        10233       1825        14634       3450
# Caterpillar        A6      A6        14488       2883        13317       3091
# Ford               A7      A7        10938       2231        12080       2142
# Navistar           A8      A8        11392       2280         8922       1834
# Volvo              A9      A9        12601       2515         9707       1869
# Peterbilt         A10     A10        13699       2583        11583       2077
# Peterbilt         A11     A11        12447       2596        15726       3145
# ...

# %%
truck_data.iloc[1:10]
# Out:
#   driverid truckid        model  jun13_miles  jun13_gas  may13_miles  \
# 1       A2      A2         Ford        12058       2335        14314
# 2       A3      A3         Ford        13652       2899        12075
# 3       A4      A4     Kenworth        12687       2439        10680
# 4       A5      A5         Hino        10233       1825        14634
# 5       A6      A6  Caterpillar        14488       2883        13317
# 6       A7      A7         Ford        10938       2231        12080
# 7       A8      A8     Navistar        11392       2280         8922
# 8       A9      A9        Volvo        12601       2515         9707
# 9      A10     A10    Peterbilt        13699       2583        11583
#
#    may13_gas  apr13_miles  apr13_gas  mar13_miles    ...      may09_miles  \
# 1       2648        11050       2323        14114    ...            13912
# 2       2603        12277       2792         9642    ...             9821
# ...

# %%
dat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-58f97bc2b878> in <module>()
# ----> 1 dat
#
# NameError: name 'dat' is not defined

# %%
truck_data.columns
# Out:
# Index(['driverid', 'truckid', 'model', 'jun13_miles', 'jun13_gas',
#        'may13_miles', 'may13_gas', 'apr13_miles', 'apr13_gas', 'mar13_miles',
#        ...
#        'may09_miles', 'may09_gas', 'apr09_miles', 'apr09_gas', 'mar09_miles',
#        'mar09_gas', 'feb09_miles', 'feb09_gas', 'jan09_miles', 'jan09_gas'],
#       dtype='object', length=111)

# %%
truck_data.index
# Out:
# Index(['Freightliner', 'Ford', 'Ford', 'Kenworth', 'Hino', 'Caterpillar',
#        'Ford', 'Navistar', 'Volvo', 'Peterbilt', 'Peterbilt', 'Caterpillar',
#        'Oshkosh', 'Crane', 'Ford', 'Navistar', 'Western Star', 'Caterpillar',
#        'Caterpillar', 'Western Star', 'Hino', 'Caterpillar', 'Ford',
#        'Navistar', 'Volvo', 'Peterbilt', 'Peterbilt', 'Caterpillar', 'Ford',
#        'Ford', 'Kenworth', 'Hino', 'Caterpillar', 'Freightliner', 'Ford',
#        'Ford', 'Kenworth', 'Hino', 'Caterpillar', 'Ford', 'Navistar', 'Volvo',
#        'Peterbilt', 'Peterbilt', 'Caterpillar', 'Volvo', 'Peterbilt',
#        'Peterbilt', 'Caterpillar', 'Oshkosh', 'Crane', 'Ford', 'Navistar',
#        'Western Star', 'Caterpillar', 'Caterpillar', 'Freightliner', 'Ford',
#        'Ford', 'Caterpillar', 'Freightliner', 'Ford', 'Ford', 'Kenworth',
#        'Hino', 'Caterpillar', 'Ford', 'Navistar', 'Volvo', 'Peterbilt',
#        'Peterbilt', 'Caterpillar', 'Oshkosh', 'Kenworth', 'Hino',
# ...

# %%
truck_data.describe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0653393c2b43> in <module>()
# ----> 1 truck_data.describe
#
# NameError: name 'truck_data' is not defined

# %%
truck_data.describe()
# Out:
#         jun13_miles    jun13_gas   may13_miles    may13_gas   apr13_miles  \
# count    100.000000   100.000000    100.000000   100.000000    100.000000
# mean   12043.120000  2456.320000  12188.820000  2422.140000  11566.620000
# std     1777.444655   436.052075   1931.169601   414.699843   1767.215174
# min     8490.000000  1593.000000   8304.000000  1637.000000   8307.000000
# 25%    10669.500000  2091.000000  10460.000000  2076.500000  10122.250000
# 50%    12048.000000  2438.500000  12632.500000  2472.000000  11420.500000
# 75%    13533.000000  2744.750000  13727.750000  2749.500000  12748.250000
# max    15548.000000  3446.000000  15726.000000  3450.000000  15470.000000
#
#         apr13_gas   mar13_miles    mar13_gas   feb13_miles    feb13_gas  \
# count   100.00000    100.000000   100.000000    100.000000   100.000000
# mean   2365.40000  12000.290000  2380.190000  11762.060000  2375.390000
# std     449.25712   1849.692266   422.391237   1646.470512   361.599139
# ...

# %%
import numpy as np

# %%
r=np.arange(0,8)
truck_data.loc[[0,1]]
# Out:
#   driverid truckid         model  jun13_miles  jun13_gas  may13_miles  \
# 0       A1      A1  Freightliner         9217       1914         8769
# 1       A2      A2          Ford        12058       2335        14314
#
#    may13_gas  apr13_miles  apr13_gas  mar13_miles    ...      may09_miles  \
# 0       1892        14234       3008        11519    ...            12073
# 1       2648        11050       2323        14114    ...            13912
#
#    may09_gas  apr09_miles  apr09_gas  mar09_miles  mar09_gas  feb09_miles  \
# 0       2642        15276       2642         9880       2642        13861
# 1       1827        11892       1827        15158       1827        12774
#
#    feb09_gas  jan09_miles  jan09_gas
# 0       2642        11176       2642
# 1       1827        11743       1827
#
# [2 rows x 111 columns]

# %%
truck_data[np.arange(1,3)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-1e8b1aed5331> in <module>()
# ----> 1 truck_data[np.arange(1,3)]
#
# /home/deepak-kumar-jha/Downloads/ENTER/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2054         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2055             # either boolean or fancy integer index
# -> 2056             return self._getitem_array(key)
#    2057         elif isinstance(key, DataFrame):
#    2058             return self._getitem_frame(key)
#
# /home/deepak-kumar-jha/Downloads/ENTER/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2098             return self.take(indexer, axis=0, convert=False)
#    2099         else:
# -> 2100             indexer = self.loc._convert_to_indexer(key, axis=1)
# ...

# %%
truck_data[::-1]
# Out:
#    driverid truckid         model  jun13_miles  jun13_gas  may13_miles  \
# 99     A100    A100     Peterbilt        13019       2329        13991
# 98      A99     A99     Peterbilt        13912       2720        12916
# 97      A98     A98         Volvo        10732       2238        11661
# 96      A97     A97   Caterpillar        13489       2425        10189
# 95      A96     A96     Peterbilt        12738       2637        13991
# 94      A95     A95     Peterbilt        14670       3328        12329
# 93      A94     A94         Volvo        13296       2474        12810
# 92      A93     A93      Navistar         9433       1902        13849
# 91      A92     A92         Volvo        13617       2960        10046
# 90      A91     A91      Navistar        10348       1970        11209
# 89      A90     A90          Ford         9163       1992        11374
# 88      A89     A89   Caterpillar        14955       3344        14587
# ...

# %%
truck_data
# Out:
#    driverid truckid         model  jun13_miles  jun13_gas  may13_miles  \
# 0        A1      A1  Freightliner         9217       1914         8769
# 1        A2      A2          Ford        12058       2335        14314
# 2        A3      A3          Ford        13652       2899        12075
# 3        A4      A4      Kenworth        12687       2439        10680
# 4        A5      A5          Hino        10233       1825        14634
# 5        A6      A6   Caterpillar        14488       2883        13317
# 6        A7      A7          Ford        10938       2231        12080
# 7        A8      A8      Navistar        11392       2280         8922
# 8        A9      A9         Volvo        12601       2515         9707
# 9       A10     A10     Peterbilt        13699       2583        11583
# 10      A11     A11     Peterbilt        12447       2596        15726
# 11      A12     A12   Caterpillar        10006       2055        10307
# ...

# %%
mod = truck_data.set_index('model')

# %%
mod
# Out:
#              driverid truckid  jun13_miles  jun13_gas  may13_miles  may13_gas  \
# model
# Freightliner       A1      A1         9217       1914         8769       1892
# Ford               A2      A2        12058       2335        14314       2648
# Ford               A3      A3        13652       2899        12075       2603
# Kenworth           A4      A4        12687       2439        10680       2083
# Hino               A5      A5        10233       1825        14634       3450
# Caterpillar        A6      A6        14488       2883        13317       3091
# Ford               A7      A7        10938       2231        12080       2142
# Navistar           A8      A8        11392       2280         8922       1834
# Volvo              A9      A9        12601       2515         9707       1869
# Peterbilt         A10     A10        13699       2583        11583       2077
# Peterbilt         A11     A11        12447       2596        15726       3145
# ...

# %%
truck_data['Volvo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/deepak-kumar-jha/Downloads/ENTER/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'Volvo'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
Dj_dict={
    'Dj1':{'A1':'1','A2':'2','A3':'3','A4':'4','A5':'5','A6':'6'},
    'Dj2':{'A1':'21','A2':'22','A3':'23','A4':'24','A5':'25','A6':'26'},
    'Dj3':{'A1':'31','A2':'32','A3':'33','A4':'34','A5':'35','A6':'36'},
    'Dj4':{'A1':'41','A2':'42','A3':'43','A4':'44','A5':'45','A6':'46'},
    'Dj5':{'A1':'51','A2':'52','A3':'53','A4':'54','A5':'55','A6':'56'}
}

djdic = pd.DataFrame(Dj_dict)

# %%
djdic
# Out:
#    Dj1 Dj2 Dj3 Dj4 Dj5
# A1   1  21  31  41  51
# A2   2  22  32  42  52
# A3   3  23  33  43  53
# A4   4  24  34  44  54
# A5   5  25  35  45  55
# A6   6  26  36  46  56

# %%
djdic[['Dj1']]
# Out:
#    Dj1
# A1   1
# A2   2
# A3   3
# A4   4
# A5   5
# A6   6
