# %%
import pandas as pd

house_rent=pd.read_csv('house_rental.csv')

# %%
import os
print(os.path)
# Out:
# <module 'posixpath' from '/home/deepak-kumar-jha/Downloads/ENTER/lib/python3.6/posixpath.py'>

# %%
house_rent
# Out:
#      Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 0             1  1177.698      2           7        2            2         2
# 1             2  2134.800      5           7        4            2         2
# 2             3  1138.560      5           7        2            2         1
# 3             4  1458.780      2           7        3            2         2
# 4             5   967.776     11          14        3            2         2
# 5             6  1127.886     11          12        4            2         2
# 6             7  1352.040      5           7        3            2         1
# 7             8   757.854      5          14        1            0         1
# 8             9  1152.792     10          12        3            2         2
# 9            10  1423.200      4           5        4            2         2
# 10           11   668.904      4          11        1            1         1
# ...

# %%
house_rent.set_index(['Sqft','Price'])
# Out:
#                  Unnamed: 0  Floor  TotalFloor  Bedroom  Living.Room  Bathroom
# Sqft     Price
# 1177.698 62000            1      2           7        2            2         2
# 2134.800 78000            2      5           7        4            2         2
# 1138.560 58000            3      5           7        2            2         1
# 1458.780 45000            4      2           7        3            2         2
# 967.776  45000            5     11          14        3            2         2
# 1127.886 148000           6     11          12        4            2         2
# 1352.040 58000            7      5           7        3            2         1
# 757.854  48000            8      5          14        1            0         1
# 1152.792 45000            9     10          12        3            2         2
# 1423.200 65000           10      4           5        4            2         2
# 668.904  31000           11      4          11        1            1         1
# ...

# %%
house_rent.describe()
# Out:
#        Unnamed: 0         Sqft       Floor  TotalFloor     Bedroom  \
# count  645.000000   645.000000  645.000000  645.000000  645.000000
# mean   325.159690  1527.656260    5.939535   10.855814    2.837209
# std    187.312152   767.386531    3.884721    4.996208    1.010740
# min      1.000000   359.358000    1.000000    1.000000    1.000000
# 25%    164.000000   925.080000    3.000000    7.000000    2.000000
# 50%    326.000000  1423.200000    5.000000   12.000000    3.000000
# 75%    487.000000  1892.856000    8.000000   14.000000    4.000000
# max    648.000000  5856.468000   22.000000   38.000000    7.000000
#
#        Living.Room    Bathroom          Price
# count   645.000000  645.000000     645.000000
# mean      1.813953    1.810853   61986.823256
# std       0.462364    0.683574   35635.091007
# min       0.000000    0.000000    6100.000000
# 25%       2.000000    1.000000   39000.000000
# 50%       2.000000    2.000000   50000.000000
# ...

# %%
sqft_max = house_rent[(house_rent['Price']==250000.000000)]['Sqft']

# %%
sqft
# Out:
# 286    3504.63
# Name: Sqft, dtype: float64

# %%
sqft_min = house_rent[(house_rent['Price']==6100)]['Sqft']

# %%
sqft_min
# Out:
# 609    996.24
# Name: Sqft, dtype: float64

# %%
total_floor_max=house_rent[(house_rent['TotalFloor']==38)]

# %%
total_floor_max
# Out:
#      Unnamed: 0    Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 147         149  4981.2      3          38        3            2         3
#
#       Price
# 147  225000

# %%
import numpy as np

house_rent['Price'].max()
house_rent['Price'].min()
# Out:
# 6100

# %%
house_rent.iloc[[1,0]]
# Out:
#    Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 1           2  2134.800      5           7        4            2         2
# 0           1  1177.698      2           7        2            2         2
#
#    Price
# 1  78000
# 0  62000

# %%
house_rent.ix[[1,0]]
# Out:
# /home/deepak-kumar-jha/Downloads/ENTER/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.
#    Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 1           2  2134.800      5           7        4            2         2
# 0           1  1177.698      2           7        2            2         2
#
#    Price
# 1  78000
# 0  62000

# %%
house_rent.iloc[[0]]
# Out:
#    Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 0           1  1177.698      2           7        2            2         2
#
#    Price
# 0  62000
